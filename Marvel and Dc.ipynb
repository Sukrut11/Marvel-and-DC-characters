# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
marvel=pd.read_csv("C://Users//user//charcters_stats.csv")

# %%
marvel.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Abomination       bad            63        80     53          90     55
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436

# %%
marvel.size
# Out:
# 5499

# %%
marvel.isnull().sum()
# Out:
# Name            0
# Alignment       3
# Intelligence    0
# Strength        0
# Speed           0
# Durability      0
# Power           0
# Combat          0
# Total           0
# dtype: int64

# %%
marvel["Alignment"].value_counts()
# Out:
# good       432
# bad        165
# neutral     11
# Name: Alignment, dtype: int64

# %%
good=marvel[marvel["Alignment"]=="good"]

# %%
good.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 6  Adam Monroe      good            63        10     12         100     71
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 6      64    320

# %%
good_max_speed=good.sort_values(by=["Speed"],ascending=False).head()

# %%
good_max_speed
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 231       Flash III      good            63        10    100          60
# 304  Jack of Hearts      good            63        55    100          30
# 295         Impulse      good            50        10    100          60
# 525        Stardust      good            88        85    100         110
# 447     Quicksilver      good            63        28    100          60
#
#      Power  Combat  Total
# 231     83      32    348
# 304     70      30    348
# 295     63      60    343
# 525    100      85    568
# 447     57      56    364

# %%
good.sort_values(by=["Power"],ascending=False).head()
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 609        Zatanna      good            75        10     23          28
# 546           Thor      good            69       100     92         100
# 511          Spawn      good            75        60     50          90
# 69   Beta Ray Bill      good            63        80     35          95
# 70        Beyonder      good            88       100     23         100
#
#      Power  Combat  Total
# 609    100      56    292
# 546    100      85    546
# 511    100      95    470
# 69     100      84    457
# 70     100      56    467

# %%
good_max_power=good[good["Power"]==100]

# %%
good_max_power.shape
# Out:
# (33, 9)

# %%
good_max_power
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 69       Beta Ray Bill      good            63        80     35          95
# 70            Beyonder      good            88       100     23         100
# 85          Black Bolt      good            75        67    100          84
# 129              Cable      good            88        48     23          56
# 185            Deadman      good            50        10     33         100
# 196        Doctor Fate      good            81        16     25          80
# 198     Doctor Strange      good           100        10     12          84
# 204       Dr Manhattan      good            88        32     42          95
# 226          Firestorm      good            50        53     58          56
# 251               Goku      good            56       100     75          90
# 266         Hal Jordan      good            63        90     53          64
# ...

# %%
good_total=good.sort_values(by=["Total"],ascending=False).head()

# %%
good_total
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 361  Martian Manhunter      good           100       100     96         100
# 537           Superman      good           100       100    100         100
# 525           Stardust      good            88        85    100         110
# 546               Thor      good            69       100     92         100
# 536          Supergirl      good            94        98     92         100
#
#      Power  Combat  Total
# 361    100      85    581
# 537     94      85    579
# 525    100      85    568
# 546    100      85    546
# 536     85      75    544

# %%
plt.figure(figsize=(6,6))
plt.bar(list(good_max_power["Name"][0:5]),list(good_total["Total"][0:5]),color="g")
plt.show()

# %%
bad=marvel[marvel["Alignment"]=="bad"]

# %%
bad.head()
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 4   Abomination       bad            63        80     53          90     55
# 5       Abraxas       bad            88       100     83          99    100
# 11   Air-Walker       bad            50        85    100          85    100
# 16        Amazo       bad            75       100    100         100    100
# 17         Ammo       bad             1         1      1           1      0
#
#     Combat  Total
# 4       95    436
# 5       56    526
# 11      40    460
# 16     100    575
# 17       1      5

# %%
bad_max_power=bad.sort_values(by=["Power"],ascending=False).head()

# %%
bad_max_power.head()
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 564           Ultron       bad            88        83     42         100
# 422        Onslaught       bad            88        85     47         100
# 180         Darkseid       bad            88       100     23         100
# 501         Sinestro       bad            75        80     53          64
# 386  Mister Mxyzptlk       bad           113        10     12          14
#
#      Power  Combat  Total
# 564    100      64    477
# 422    100      85    505
# 180    100      95    506
# 501    100      56    428
# 386    100      28    277

# %%
bad_max_speed=bad.sort_values(by=["Speed"],ascending=False).head()

# %%
bad_max_speed
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 610            Zoom       bad            50        10    100          28
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 535  Superboy-Prime       bad            94       100    100         100
# 242     General Zod       bad            94       100     96         100
#
#      Power  Combat  Total
# 610     72      28    288
# 11     100      40    460
# 16     100     100    575
# 535    100      85    579
# 242     94      95    579

# %%
bad_max_power=bad.sort_values(by=["Power"],ascending=False).head()

# %%
bad_max_power
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 564           Ultron       bad            88        83     42         100
# 422        Onslaught       bad            88        85     47         100
# 180         Darkseid       bad            88       100     23         100
# 501         Sinestro       bad            75        80     53          64
# 386  Mister Mxyzptlk       bad           113        10     12          14
#
#      Power  Combat  Total
# 564    100      64    477
# 422    100      85    505
# 180    100      95    506
# 501    100      56    428
# 386    100      28    277

# %%
bad_max_combat=bad.sort_values(by=["Combat"],ascending=False).head()

# %%
bad_max_combat
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 475    Sabretooth       bad            55        53     25          90     28
# 16          Amazo       bad            75       100    100         100    100
# 449  Ra's Al Ghul       bad           100        28     32          42     27
# 464     Rick Flag       bad            88        11     23          28     19
# 180      Darkseid       bad            88       100     23         100    100
#
#      Combat  Total
# 475     100    351
# 16      100    575
# 449     100    329
# 464      95    264
# 180      95    506

# %%
bad_max_total=bad.sort_values(by=["Total"],ascending=False).head()

# %%
bad_max_total
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 535  Superboy-Prime       bad            94       100    100         100
# 242     General Zod       bad            94       100     96         100
# 16            Amazo       bad            75       100    100         100
# 203        Dormammu       bad            88        95     83         100
# 201        Doomsday       bad            88        80     67         120
#
#      Power  Combat  Total
# 535    100      85    579
# 242     94      95    579
# 16     100     100    575
# 203    100      80    546
# 201    100      90    545

# %%
plt.figure(figsize=(6,6))
plt.bar(list(bad_max_total["Name"][0:5]),list(bad_max_total["Total"][0:5]),color="g")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.hist(good["Total"])
plt.title("Distribution of Total power of Super Heroes")
plt.xlabel=("Total Qualities")

# %%
plt.figure(figsize=(10,5))
plt.hist(bad["Total"])
plt.title("Distribution of Total power of Super Heroes")
plt.xlabel=("Total Qualities")

# %%
sns.lineplot(x="Name",y="Total",data=bad_max_total,color="red",linestyle="dashdot")
plt.show()

# %%
names=list(good_total[0:5].keys())[0:5]

# %%
names
# Out:
# ['Name', 'Alignment', 'Intelligence', 'Strength', 'Speed']

# %%
plt.figure(figsize=(10,5))
sns.barplot(x="Name",y="Total",data=bad_max_total,hue="Total")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x="Name",y="Total",data=good_total,hue="Total")
plt.show()

# %%
sns.distplot(marvel["Speed"],hist=True)
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.histplot(marvel["Power"])
plt.show()

# %%
sns.histplot(marvel["Total"])
plt.show()

# %%
sns.jointplot(x="Speed",y="Total",data=good,color="Gold",kind="reg")
plt.show()

# %%
sns.jointplot(x="Power",y="Total",data=bad,color="red",kind="reg")
plt.show()
